WV_rates=[35.8, 36.4, 36.4, 36.7, 37.2, 37.7, 37.9, 37.6, 37.6, 37.9, 37.8, 38.1, 38.5, 38.3, 38.0, 37.9, 37.5, 37.6, 36.9, 36.2]
WI_rates=[41.4, 41.4, 41.5, 41.2, 40.8, 41.3, 41.4, 41.6, 41.7, 41.6, 41.3, 42.2, 42.5, 42.8, 42.6, 42.5, 42.3, 42.1, 40.7, 40.4]
WY_rates=[34.3, 35.5, 35.8, 36.3, 37.0, 37.7, 38.1, 37.7, 36.9, 36.6, 36.8, 37.6, 37.8, 38.1, 38.5, 39.2, 39.4, 38.7, 37.8, 37.4]

days=len(AL_rates)

#Matrix containing the percent of all the states' population staying at home
state_rates=[AL_rates, AK_rates, AZ_rates, AR_rates, CA_rates, CO_rates, CT_rates, DE_rates, FL_rates, GA_rates,HI_rates, ID_rates, IL_rates, IN_rates, IA_rates, KS_rates, KY_rates, LA_rates, ME_rates, MD_rates, MA_rates, MI_rates, MN_rates, MS_rates, MO_rates, MT_rates, NE_rates, NV_rates, NH_rates, NJ_rates, NM_rates, NY_rates, NC_rates, ND_rates, OH_rates, OK_rates, OR_rates, PA_rates, RI_rates, SC_rates, SD_rates, TN_rates, TX_rates, UT_rates, VT_rates, VA_rates, WA_rates, WV_rates, WI_rates, WY_rates]

#Code for creating an average stay at home percent for each state (alphabetical order) & adding to a matrix
state_averages=[]

for i in range(50):
    total=0
    
    for j in range(days):
        total=total+state_rates[i][j]
    state_averages.append(total/days)

# %%
import numpy as np
import matplotlib.pyplot as plt

#Percent of population with internet access by state
AL_access=80
AK_access=74
AZ_access=87
AR_access=75
CA_access=95
CO_access=90
CT_access=99
DE_access=97
FL_access=93
GA_access=91
HI_access=98
ID_access=82
IL_access=91
IN_access=83
IA_access=85
KS_access=85
KY_access=84
LA_access=81
ME_access=88
MD_access=96
MA_access=97
MI_access=88
MN_access=88
MS_access=66
MO_access=80
MT_access=69
NE_access=84
NV_access=92
NH_access=93
NJ_access=97
NM_access=80
NY_access=98
NC_access=93
ND_access=86
OH_access=92
OK_access=73
OR_access=90
PA_access=94
RI_access=98
SC_access=82
SD_access=89
TN_access=87
TX_access=89
UT_access=94
VT_access=83
VA_access=89
WA_access=97
WV_access=70
WI_access=87
WY_access=77

#Matrix containing all the states' internet access percentages
state_access=[AL_access, AK_access, AZ_access, AR_access, CA_access, CO_access, CT_access, DE_access, FL_access, GA_access,HI_access, ID_access, IL_access, IN_access, IA_access, KS_access, KY_access, LA_access, ME_access, MD_access, MA_access, MI_access, MN_access, MS_access, MO_access, MT_access, NE_access, NV_access, NH_access, NJ_access, NM_access, NY_access, NC_access, ND_access, OH_access, OK_access, OR_access, PA_access, RI_access, SC_access, SD_access, TN_access, TX_access, UT_access, VT_access, VA_access, WA_access, WV_access, WI_access, WY_access]

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import cov

x=np.array(state_access)
y=np.array(state_averages)

#Code for the scatterplot graph + the linear regression line

plt.scatter(state_access, state_averages)
plt.xlabel('% with Internet Access (By State)')
plt.ylabel('Average % Sheltering in Place')
plt.title('Correlation Between Staying at Home and Sheltering in Place')

m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color="red")
plt.savefig('graph1.png', dpi=1920)

#Code to calculate r-value (determine if the correlation is strong)

covariance = np.corrcoef(x, y)
r = covariance[0,1]
rsquared=r**2
print ("R: " + str(r))
print ("R-squared: " + str(rsquared))
print (" ")

plt.show()
# Out:
# R: 0.7622222331549592
# R-squared: 0.580982732715733
